# %% [markdown]
# # 01 — Download & Exploratory Data Analysis (EDA)
#
# **Goal:**
# - Download daily price data for sector ETFs.
# - Compute daily log returns.
# - Visualize price trends, volatility, and correlations.
# - Export summary statistics for later modeling steps.
#
# **Tickers:** `XLK, XLF, XLI, XLV`
# Time Period: **2013–2023**

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd

from quantcopula.data import get_prices
from quantcopula.plotting import plot_prices, plot_returns, plot_correlation_heatmap

TICKERS = ["XLK", "XLF", "XLI", "XLV"]
START_DATE = "2013-01-01"
END_DATE = "2023-12-31"

os.makedirs("data/processed", exist_ok=True)
os.makedirs("figures", exist_ok=True)
# Out:
# [autoreload of six failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 330, in update_class
#     old_obj = getattr(old, key)
#               ^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\six.py", line 98, in __get__
#     setattr(obj, self.name, result)  # Invokes __set__.
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'filter'
# ]
# [autoreload of packaging.utils failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: canonicalize_version() requires a code object with 0 free vars, not 1838246002690
# ]
# C:\Users\Admin\anaconda3\Lib\importlib\__init__.py:131: UserWarning: The NumPy module was reloaded (imported a second time). This can in some cases result in small but subtle issues and is discouraged.
#   _bootstrap._exec(spec, module)
# C:\Users\Admin\anaconda3\Lib\site-packages\PIL\Image.py:116: RuntimeWarning: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 10.4.0
# Pillow version: 12.0.0
#   warnings.warn(str(v), RuntimeWarning)
# [autoreload of PIL.Image failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\PIL\Image.py", line 103, in <module>
#     raise ImportError(msg)
# ImportError: The _imaging extension was built for another version of Pillow or PIL:
# Core version: 10.4.0
# Pillow version: 12.0.0
# ]
# [autoreload of pyparsing.core failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: can_parse_next() requires a code object with 0 free vars, not 1838246002689
# ]
# [autoreload of pyparsing.common failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: int() requires a code object with 2 free vars, not 1838246002689
# ]
# [autoreload of scipy.stats._continuous_distns failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_continuous_distns.py", line 162, in <module>
#     ksone = ksone_gen(a=0.0, b=1.0, name='ksone')
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 1806, in __init__
#     super().__init__(seed)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 643, in __init__
#     self._random_state = check_random_state(seed)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\_lib\_util.py", line 265, in check_random_state
#     return np.random.mtrand._rand
#            ^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy.random' has no attribute 'mtrand'. Did you mean: 'rand'?
# ]
# [autoreload of scipy.interpolate._interpolate failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'interp1d' object layout differs from 'interp1d'
# ]
# [autoreload of scipy.stats._discrete_distns failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_discrete_distns.py", line 108, in <module>
#     binom = binom_gen(name='binom')
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 3225, in __init__
#     super().__init__(seed)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 643, in __init__
#     self._random_state = check_random_state(seed)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\_lib\_util.py", line 265, in check_random_state
#     return np.random.mtrand._rand
#            ^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy.random' has no attribute 'mtrand'. Did you mean: 'rand'?
# ]
# [autoreload of scipy.stats._levy_stable failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_levy_stable\__init__.py", line 1224, in <module>
#     levy_stable = levy_stable_gen(name="levy_stable")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 1806, in __init__
#     super().__init__(seed)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py", line 643, in __init__
#     self._random_state = check_random_state(seed)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\_lib\_util.py", line 265, in check_random_state
#     return np.random.mtrand._rand
#            ^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy.random' has no attribute 'mtrand'. Did you mean: 'rand'?
# ]
# [autoreload of scipy.stats._multivariate failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_multivariate.py", line 854, in <module>
#     multivariate_normal = multivariate_normal_gen()
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_multivariate.py", line 389, in __init__
#     super().__init__(seed)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\stats\_multivariate.py", line 212, in __init__
#     self._random_state = check_random_state(seed)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\scipy\_lib\_util.py", line 265, in check_random_state
#     return np.random.mtrand._rand
#            ^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy.random' has no attribute 'mtrand'. Did you mean: 'rand'?
# ]
# [autoreload of numpy.testing._private.utils failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\numpy\testing\_private\utils.py", line 57, in <module>
#     HAS_LAPACK64 = numpy.linalg._umath_linalg._ilp64
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy.linalg' has no attribute '_umath_linalg'
# ]
# [autoreload of numpy.testing failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\numpy\testing\__init__.py", line 17, in <module>
#     _private.utils.__all__ + ['TestCase', 'overrides']
#     ^^^^^^^^^^^^^^
# AttributeError: module 'numpy.testing._private' has no attribute 'utils'
# ]
# [autoreload of soupsieve.__meta__ failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'Version' object layout differs from 'Version'
# ]
# [autoreload of soupsieve.css_types failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'Selector' object layout differs from 'Selector'
# ]
# [autoreload of frozendict failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\frozendict\__init__.py", line 54, in <module>
#     __all__ = _frozendict_py.__all__
#               ^^^^^^^^^^^^^^
# NameError: name '_frozendict_py' is not defined. Did you mean: 'frozendict'?
# ]
# [autoreload of peewee failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: '_Namespace' object layout differs from '_Namespace'
# ]
# [autoreload of charset_normalizer.cd failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\charset_normalizer\cd.py", line 16, in <module>
#     from .md import is_suspiciously_successive_range
# ImportError: cannot import name 'is_suspiciously_successive_range' from 'charset_normalizer.md' (C:\Users\Admin\anaconda3\Lib\site-packages\charset_normalizer\md.cp312-win_amd64.pyd)
# ]
# [autoreload of charset_normalizer.api failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\charset_normalizer\api.py", line 14, in <module>
#     from .md import mess_ratio
# ImportError: cannot import name 'mess_ratio' from 'charset_normalizer.md' (C:\Users\Admin\anaconda3\Lib\site-packages\charset_normalizer\md.cp312-win_amd64.pyd)
# ]
# [autoreload of matplotlib._mathtext failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: float() requires a code object with 2 free vars, not 1838246002689
# ]
# [autoreload of matplotlib.widgets failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 1838246002692
# ]
# [autoreload of matplotlib.backend_bases failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: start() requires a code object with 10 free vars, not 1838246002688
# ]
# [autoreload of matplotlib.axis failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: set_ticklabels() requires a code object with 0 free vars, not 1838246002692
# ]
# [autoreload of matplotlib.gridspec failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_grid_positions() requires a code object with 0 free vars, not 1838246002698
# ]
# [autoreload of matplotlib.axes._axes failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: plot_date() requires a code object with 2 free vars, not 1838246002694
# ]
# [autoreload of matplotlib.axes failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _SubplotBaseMeta object
# ]
# [autoreload of matplotlib.pyplot failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\pyplot.py", line 673, in <module>
#     @_copy_docstring_and_deprecators(matplotlib.rc_context)
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\matplotlib\pyplot.py", line 178, in _copy_docstring_and_deprecators
#     potential_decorator = _api.deprecation.DECORATORS.get(method)
#                           ^^^^^^^^^^^^^^^^
# AttributeError: module 'matplotlib._api' has no attribute 'deprecation'. Did you mean: 'deprecated'?
# ]
# [autoreload of yfinance.data failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to SingletonMeta object
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
prices = get_prices(TICKERS, START_DATE, END_DATE, cache_path="data/raw/prices.parquet", auto_adjust=False)
prices = prices.dropna(how="any")
prices.tail()
# Out:
# [autoreload of dateutil.tz._factories failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _TzSingleton object
# ]
# [autoreload of pandas._testing failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\importlib\__init__.py", line 131, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 866, in _exec
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\pandas\_testing\__init__.py", line 405, in <module>
#     cython_table = pd.core.common._cython_table.items()
#                    ^^^^^^^^^^^^^^
# AttributeError: module 'pandas.core' has no attribute 'common'
# ]
# [autoreload of dateutil.rrule failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'weekday' object layout differs from 'weekday'
# ]
# [autoreload of bs4.element failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 371, in update_property
#     update_generic(old.fget, new.fget)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: alias() requires a code object with 1 free vars, not 1838246002691
# ]
# [autoreload of bs4 failed: Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 349, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 388, in <lambda>
#     lambda a, b: update_function(a.__func__, b.__func__),
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\anaconda3\Lib\site-packages\IPython\extensions\autoreload.py", line 309, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _decode_markup() requires a code object with 0 free vars, not 1838246002691
# ]
#
# 4 Failed downloads:
# ['XLK', 'XLF', 'XLV', 'XLI']: TypeError('super(type, obj): obj must be an instance or subtype of type')

# %% [markdown]
# ## Data Snapshot
# We expect a DateTime index and one column per ticker (Adj Close).
# Missing values are dropped to align trading calendars across ETFs.

# %%
log_returns = np.log(prices / prices.shift(1)).dropna(how="any")
log_returns.tail()

# %% [markdown]
# ## Visualizations
# We save figures to `figures/` so they can be embedded in the README or reports.

# %%
plot_prices(prices, out_path="figures/prices.png", title="Sector ETF Prices (2013–2023)")
plot_returns(log_returns, out_path="figures/log_returns.png")
plot_correlation_heatmap(log_returns, out_path="figures/corr_heatmap.png")

# %%
plot_prices(prices, out_path="figures/prices.png", title="Sector ETF Prices (2013–2023)")
plot_returns(log_returns, out_path="figures/log_returns.png")
plot_correlation_heatmap(log_returns, out_path="figures/corr_heatmap.png")

# %%
summary = log_returns.describe().T
summary["skew"] = log_returns.skew()
summary["kurtosis"] = log_returns.kurtosis()
summary.round(4).to_csv("data/processed/summary_stats.csv")
summary.round(4)

# %% [markdown]
# ## Key Takeaways
#
# - **Volatility:** Standard deviations differ across sectors (e.g., Technology typically higher).
# - **Tail risk:** Positive kurtosis indicates **fat tails**, supporting the use of **t-distribution margins**.
# - **Dependence:** Correlation heatmap reveals co-movement strength between sectors, important for copula modeling.

# %%
START_ALT = "2020-01-01"
END_ALT = END_DATE

prices_alt = get_prices(
    TICKERS,
    START_ALT,
    END_ALT,
    cache_path="data/raw/prices.parquet",
    auto_adjust=False,
).dropna(how="any")

log_returns_alt = np.log(prices_alt / prices_alt.shift(1)).dropna(how="any")

pd.DataFrame({
    "Std (2013–2023)": log_returns.std(),
    "Std (2020–present)": log_returns_alt.std(),
}).round(4)

# %% [markdown]
# **Next:** `02_fit_margins_t_and_PIT.ipynb`
# Fit Student-t marginals per asset and transform returns → uniforms (PIT).
